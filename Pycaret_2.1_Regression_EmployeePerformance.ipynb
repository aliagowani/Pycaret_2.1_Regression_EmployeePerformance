# %% [markdown]
# Name: Ali Gowani <br>
# Contact: https://www.linkedin.com/in/aliagowani/<br><br>
#
# Title: Regression Experiment for Intelligent Contact Center Employee performance<br>
# Pycaret Version: 2.1<br><br>
# Created: Monday, August 24, 2020 <br>
# Updated: Thursday, September 3, 2020 <br>
# <br>
#
# Use Jupyter Notebook Viewer to view this notebook properly: https://nbviewer.jupyter.org/github/aliagowani/Pycaret_2.1_Regression_EmployeePerformance/blob/master/Pycaret_2.1_Regression_EmployeePerformance.ipynb
#
# ## 0. Overview: Real-Life Employee Performance Case in Machine Learning (Regression) using Pycaret 2.1
#
# We are going to utilize a low-code Machine Learning Python library, Pycaret (version 2.1), to predict the First Call Resolution (FCR) metric for Customer Service Agents (Employees) in Call Centers. FCR is an important metric in a call center as it indicates the percentage of issues that were resolved when the customer called the first time. We want to ensure that customers do not keep calling back to resolve an issue as it costs the company money when the issue is not resolved the first time.
#
# Below is the approach we will take to predict a Customer Service Agent or Contact Agents FCR metric:
# <ol>
# <li>Conduct Exploratory Data Analysis (EDA) on the real data from a global call center.</li>
# <li>Execute regression models to determine how accurately we can predict the FCR metric for each employee.</li>
# <li>Create a classification indicator to determine whether predicting an employee's increase or decrease in FCR metric performance is more meaningful than regression.</li>
# </ol>
#
# We will leverage a real-case data from a business process outsourcer (BPO) that supports many Fortune 500 companies. *Note: dataset has been sanitized of personal information as it is a real dataset.
#
# Let's get started!

# %% [markdown]
# ## 1. Load Libraries

# %%
# Import libraries for data processing.
import numpy as np
import pandas as pd
import warnings
import time
warnings.filterwarnings('ignore')

# Import libraries for visualization and set default values.
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['seaborn'])

# Import sklearn and configure display setting.
#from sklearn import set_config
#set_config(display='text')

# %%
# Install and import Pycaret library for transformation and classification.
# !pip install pycaret
from pycaret.regression import *

# Confirm Pycaret version is 2.1
from pycaret.utils import version
print('Confirm Pycaret version is 2.2.x?')
print('Pycaret Version: ', version())
# Out:
# Confirm Pycaret version is 2.2.x?
# Pycaret Version:  2.2.3

# %% [markdown]
# ## 2. Load Dataset

# %%
# Load Dataset.
# url = 'https://raw.githubusercontent.com/aliagowani/Pycaret_2.1_Regression_EmployeePerformance/master/employee_performance.csv?token=AMLWIYQHZO4XANFWX3IP5B27LGQIY'
# dataset = pd.read_csv(url)

# Initiate local directory
import os
os.getcwd()
os.chdir('/Users/aliagowani/Downloads')
dataset = pd.read_csv('model data fcr with features and acutal v2.csv')

# Drop observations where Actual Value is NaN as this is our Label
dataset = dataset.dropna(axis=0, subset=['actualvalue'])

# Create a classification feature to determine whether the agent increased or decreased in performance
dataset['actualvalue_class'] = np.where(dataset['actualvalue'] >= dataset['Friday'], '1', '0').astype(int)

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
# Below is a high-level description of each feature. The data set is comprised of 102 agents and we have 19 features to evaluate. The data is between the time period of June 1, 2020 and July 31, 2020, with the 'Actual Value' as the Actual FCR value of each agent for August 7, 2020. The goal is to create a model that predicts the FCR for an employee can have at the end of the week (Friday). 

# 'Agent_ID': unique identifier of the employee or agent.
# 'Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday': shows the FCR percent for each agent as an aggregate (mean). The higher the percentage the higher the rate at which the customer's issue was resolved in the first call. 
# 'Site': city location of the call center.
# 'Function_Field': this is the role of the employee. In our case, it should all be Agents. 
# 'tenure': tenure of the agent at the company in months. 
# 'Total number of calls': number of all phone calls taken by the agent in the given timeframe.
# 'Assistance': percentage of time the agent needed to provide additional assistance by escalating to supervisor. 
# 'Recommend': percentage of time the agent would be recommended by the customer to resolve an issue. 
# 'CSat': average survey response (on a scale from 1 (least satisfied) to 5 (most satisfied)) that the customer was satisfied with the experience. 
# 'total coaching': number of times the agent received coaching sessions from supervisor to improve FCR metric in the given timeframe. 
# 'total coaching improved': number of times the agent's FCR value increased after a week from the initial coaching. 
# 'Actual Value': the label we are trying to predict. It is the next Friday (August 7, 2020) FCR value for the agent. 
# 'FCR Week before': a strong indicator is how well the agent performed the previous Friday. This is the FCR value for the Friday before the predicted value ('Actual Value'). 

# Describe the features in the dataset, such as, count, mean, standard deviation, min, max, etc.
print("Shape of dataset (observations, features):", dataset.shape)
dataset.head(5).round(2)
# Out:
# Shape of dataset (observations, features): (418, 15)
#     Unnamed: 0  employeeid  Friday  Monday  Saturday  Sunday  Thursday  \
# 3            3    26702507   91.47   91.88    100.00   91.11       NaN
# 4            4    26702507   91.47   91.88    100.00   91.11       NaN
# 7            7    26702537  100.00   88.53    100.00   95.83       NaN
# 8            8    26702537  100.00   88.53    100.00   95.83       NaN
# 10          10    26702549  100.00   98.15     92.86   96.43       NaN
#
#     Tuesday  Wednesday  weekbefore  ncoachingid  total coaching improved  \
# 3     96.67        NaN        80.0          NaN                      NaN
# 4     96.67        NaN       100.0          NaN                      NaN
# 7     95.71        NaN       100.0          1.0                      1.0
# 8     95.71        NaN       100.0          1.0                      1.0
# 10    96.88      100.0       100.0          1.0                      1.0
#
#      csat  actualvalue  actualvalue_class
# 3   95.52        90.00                  0
# 4   95.52        90.00                  0
# 7   96.63        88.89                  0
# 8   96.63        88.89                  0
# 10  97.99        80.00                  0

# %%
dataset_corr = dataset.corr().round(4)
dataset.head(5).round(2)
# Out:
#     Unnamed: 0  employeeid  Friday  Monday  Saturday  Sunday  Thursday  \
# 3            3    26702507   91.47   91.88    100.00   91.11       NaN
# 4            4    26702507   91.47   91.88    100.00   91.11       NaN
# 7            7    26702537  100.00   88.53    100.00   95.83       NaN
# 8            8    26702537  100.00   88.53    100.00   95.83       NaN
# 10          10    26702549  100.00   98.15     92.86   96.43       NaN
#
#     Tuesday  Wednesday  weekbefore  ncoachingid  total coaching improved  \
# 3     96.67        NaN        80.0          NaN                      NaN
# 4     96.67        NaN       100.0          NaN                      NaN
# 7     95.71        NaN       100.0          1.0                      1.0
# 8     95.71        NaN       100.0          1.0                      1.0
# 10    96.88      100.0       100.0          1.0                      1.0
#
#      csat  actualvalue  actualvalue_class
# 3   95.52        90.00                  0
# 4   95.52        90.00                  0
# 7   96.63        88.89                  0
# 8   96.63        88.89                  0
# 10  97.99        80.00                  0

# %%
# Create a correlation for the dataset.
dataset_corr = dataset.corr().round(4)

# Drop Agent_ID from correlation dataset.
dataset_corr = dataset_corr.drop(['employeeid', 'Unnamed: 0'], axis=1)
dataset_corr = dataset_corr.drop(['employeeid', 'Unnamed: 0'], axis=0)

# Create a correlation matrix. Only bottom left corner valued. 
mask = np.zeros_like(dataset_corr.round(4))
mask[np.triu_indices_from(mask)] = True

# Generate the corrleation matrix (heatmap) using Seaborn. 
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(12, 10))
    ax = sns.heatmap(dataset_corr.round(2), mask=mask, vmax=1, center = 0, vmin=-1, square=True, cmap='PuOr', linewidths=.5, annot=True, annot_kws={"size": 12}, fmt='.1f')
    plt.title('Heatmap (Correlations) of Features in the Dataset', fontsize=15)
    plt.xlabel('Features', fontsize=15)
    plt.ylabel('Features', fontsize=15)
plt.show()

# %%
# Visualize the FCR for specific day in the probability density chart. 
facet = sns.FacetGrid(dataset, aspect = 3, height=5)
facet.map(sns.kdeplot, 'Sunday', shade = True, color='#4E79A7')
facet.map(sns.kdeplot, 'Monday', shade = True, color='#F28E2B')
facet.map(sns.kdeplot, 'Tuesday', shade = True, color='#59A14F')
facet.map(sns.kdeplot, 'Wednesday', shade = True, color='#E15759')
facet.map(sns.kdeplot, 'Thursday', shade = True, color='#B6992D')
facet.map(sns.kdeplot, 'Friday', shade = True, color='#499894')
facet.map(sns.kdeplot, 'Saturday', shade = True, color='#B07AA1')
facet.set(xlim = (0, dataset['Thursday'].max()))
facet.add_legend()
plt.title('First Call Resolution for Days.', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.xlabel('First Call Resolution (FCR)', fontsize=12)
plt.show()

# %%
# Visualize the dispersion of FCR values in a given day and identify the outliers. 

# Create a color set that matches the probability density chart. 
my_pal = {'Sunday': '#4E79A7','Monday': '#F28E2B', 'Tuesday': '#59A14F', 'Wednesday': '#E15759', 'Thursday': '#B6992D', 'Friday': '#499894', 'Saturday': '#B07AA1'}

# Generate a boxplot using Seaborn. 
dataset_boxplot = pd.DataFrame(data = dataset, columns = ['Sunday','Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])
plt.figure(figsize=(15,5))
sns.boxplot(x="value", y="variable", data=pd.melt(dataset_boxplot), color='#cccccc')
sns.swarmplot(x="value", y="variable", data=pd.melt(dataset_boxplot), palette=my_pal, alpha=0.5)
plt.title('First Call Resolution by Days.', fontsize=12)
plt.ylabel('Days', fontsize=12)
plt.xlabel('FCR', fontsize=12)
plt.show()

# %% [markdown]
# ## 4. Conduct Regression Model in Pycaret

# %%
# Transform dataset (transform, bin and create dummy variables) and split the dataset. In addition, we are logging experiments and plots for those experiment to be viewed later with MLflow. 
from pycaret.classification import *

reg_fcr = setup(data=dataset, target='actualvalue_class', session_id=786, transformation=True, normalize=False, train_size=0.75, numeric_features=('Sunday', 'Monday', 'Saturday', 'Thursday', 'Tuesday', 'Wednesday', 'Friday', 'ncoachingid', 'csat', 'total coaching improved', 'weekbefore'), remove_outliers=True, outliers_threshold=0.15, remove_multicollinearity=True, multicollinearity_threshold=0.9, feature_selection=True, feature_interaction=True, silent=True, ignore_features=['employeeid', 'Unnamed: 0', 'actualvalue'], trigonometry_features=True, polynomial_features=True, polynomial_degree=5, feature_selection_threshold=0.4, feature_selection_method='boruta', pca=False, log_experiment=False, experiment_name='reg_fcr_experiments', log_plots=False, fold_strategy='kfold', fold_shuffle=True, imputation_type="iterative", categorical_imputation="mode", categorical_iterative_imputer="knn", numeric_iterative_imputer="lightgbm")
# Out:
# <style  type="text/css" >
#     #T_0aeda96a_46e8_11eb_a706_acde48001122row5_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row31_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row40_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row42_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row46_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row48_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row51_col1 {
#             background-color:  lightgreen;
#         }    #T_0aeda96a_46e8_11eb_a706_acde48001122row53_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_0aeda96a_46e8_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row0_col1" class="data row0 col1" >786</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row1_col1" class="data row1 col1" >actualvalue_class</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row4_col1" class="data row4 col1" >(418, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row5_col1" class="data row5 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row6_col1" class="data row6 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row11_col1" class="data row11 col1" >(266, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row12_col1" class="data row12 col1" >(105, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row15_col1" class="data row15 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_0aeda96a_46e8_11eb_a706_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_0aeda96a_46e8_11eb_a706_acde48001122row16_col1" class="data row16 col1" >1

# %%
# Below is a list of models that Pycaret can use for regression. The ID for each regression can be used to include or exclude models for various functions.
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp           pycaret.internal.tunable.TunableMLPClassifier  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True

# %%
dataset.describe()
# Out:
#        Unnamed: 0    employeeid      Friday      Monday    Saturday  \
# count  418.000000  4.180000e+02  388.000000  359.000000  322.000000
# mean   248.464115  2.676806e+07   95.266572   94.403712   95.453846
# std    141.333440  7.608682e+05    5.370665    5.534483    4.429499
# min      3.000000  2.670251e+07   67.857500   70.832500   77.776667
# 25%    125.250000  2.670320e+07   93.334000   91.666667   92.628259
# 50%    250.000000  2.670353e+07   96.186000   95.312500   96.295000
# 75%    374.750000  2.670381e+07  100.000000  100.000000  100.000000
# max    488.000000  3.570632e+07  100.000000  100.000000  100.000000
#
#            Sunday    Thursday     Tuesday   Wednesday  weekbefore  \
# count  256.000000  306.000000  407.000000  333.000000  415.000000
# mean    94.734393   94.221967   95.195005   94.916940   95.177928
# std      6.077321    5.895096    4.890178    7.137471    9.941633
# min     50.000000   57.500000   61.666000   50.000000   33.330000
# 25%     92.466000   91.666875   93.446667   92.855000   93.330000
# 50%     95.989375   95.758375   96.010000   96.666667  100.000000
# 75%    100.000000   98.411458   98.437500  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000
#
#        ncoachingid  total coaching improved        csat  actualvalue  \
# count   312.000000                256.00000  418.000000   418.000000
# mean      3.496795                  2.37500   94.867464    94.365933
# std       2.871300                  1.57181    1.833150     5.818415
# min       1.000000                  1.00000   79.260000    50.000000
# 25%       2.000000                  1.00000   93.970000    91.300000
# 50%       3.000000                  2.00000   95.085000    95.740000
# 75%       4.000000                  3.00000   96.062500   100.000000
# max      16.000000                  8.00000   99.220000   100.000000
#
#        actualvalue_class
# count          418.00000
# mean             0.46890
# std              0.49963
# min              0.00000
# 25%              0.00000
# 50%              0.00000
# 75%              1.00000
# max              1.00000

# %%
dataset.head(10)
# Out:
#     Unnamed: 0  employeeid      Friday      Monday    Saturday     Sunday  \
# 3            3    26702507   91.468000   91.880000  100.000000  91.112000
# 4            4    26702507   91.468000   91.880000  100.000000  91.112000
# 7            7    26702537  100.000000   88.527143  100.000000  95.832857
# 8            8    26702537  100.000000   88.527143  100.000000  95.832857
# 10          10    26702549  100.000000   98.147778   92.857143  96.428571
# 11          11    26702549  100.000000   98.147778   92.857143  96.428571
# 14          14    26702594  100.000000   94.445000   89.286667        NaN
# 15          15    26702611   95.303333  100.000000         NaN        NaN
# 16          16    26702617   96.984286   91.111111   95.221429  95.328571
# 17          17    26702617   96.984286   91.111111   95.221429  95.328571
#
#      Thursday    Tuesday   Wednesday  weekbefore  ncoachingid  \
# 3         NaN  96.666000         NaN        80.0          NaN
# 4         NaN  96.666000         NaN       100.0          NaN
# 7         NaN  95.713750         NaN       100.0          1.0
# 8         NaN  95.713750         NaN       100.0          1.0
# 10        NaN  96.875000  100.000000       100.0          1.0
# 11        NaN  96.875000  100.000000        80.0          1.0
# 14  93.333333  95.101429  100.000000       100.0          1.0
# 15  97.281111  97.222222   98.765556       100.0          2.0
# 16        NaN  97.601111         NaN       100.0          NaN
# 17        NaN  97.601111         NaN       100.0          NaN
#
#     total coaching improved   csat  actualvalue  actualvalue_class
# 3                       NaN  95.52        90.00                  0
# 4                       NaN  95.52        90.00                  0
# 7                       1.0  96.63        88.89                  0
# 8                       1.0  96.63        88.89                  0
# 10                      1.0  97.99        80.00                  0
# 11                      1.0  97.99        80.00                  0
# 14                      NaN  96.19       100.00                  1
# 15                      NaN  95.14       100.00                  1
# 16                      NaN  93.87        97.06                  1
# 17                      NaN  93.87        97.06                  1

# %%
get_config('X_train').sort_index().head(10)
# Out:
#         Friday     Sunday   Thursday     Tuesday   Wednesday    Saturday  \
# 3    91.468002  91.112000  84.600988   96.666000   93.798092  100.000000
# 7   100.000000  95.832855  96.627394   95.713753   98.875468  100.000000
# 8   100.000000  95.832855  96.627394   95.713753   98.875468  100.000000
# 11  100.000000  96.428574  97.842409   96.875000  100.000000   92.857140
# 14  100.000000  82.060024  93.333336   95.101425  100.000000   89.286667
# 15   95.303337  98.609134  97.281113   97.222221   98.765556   96.716378
# 16   96.984283  95.328575  98.759916   97.601112   97.286974   95.221428
# 17   96.984283  95.328575  98.759916   97.601112   97.286974   95.221428
# 18   92.459999  88.195000  92.092658  100.000000   95.978041   92.778000
# 19  100.000000  98.611252  95.892726   93.750000   97.106020   97.500000
#
#     Wednesday_multiply_Tuesday  Sunday_multiply_Friday
# 3                  9067.086352             8333.832583
# 7                  9463.742119             9583.285522
# 8                  9463.742119             9583.285522
# 11                 9687.500000             9642.857361
# 14                 9510.142517             8206.002408
# 15                 9602.206782             9397.779552
# 16                 9495.316908             9245.373551
# 17                 9495.316908             9245.373551
# 18                 9597.804079             8154.509591
# 19                 9103.689397             9861.125183

# %%
# We can do a compare_models() function without assigning it to a variable. However, we have top 5 models selected using n_select and assigning it to top5 variable. We plan to use this for Stacking and Blending purposes. We have excluded 'RANSAC' (Random Sample Consensus) and 'KNN' (K-Nearest Neighbor) models and have adjusted the default fold value from 10 to 5. 

select_top = compare_models(n_select=2, fold=10, sort="F1")
# Out:
# <style  type="text/css" >
#     #T_965a85ea_46e8_11eb_a706_acde48001122 th {
#           text-align: left;
#     }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_965a85ea_46e8_11eb_a706_acde48001122row5_col8 {
#             text-align:  left;

# %%
select_top
# Out:
# [XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                importance_type='gain', interaction_constraints='',
#                learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                min_child_weight=1, missing=nan, monotone_constraints='()',
#                n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#                objective='binary:logistic', random_state=786, reg_alpha=0,
#                reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='auto',
#                validate_parameters=1, verbosity=0),
#  <catboost.core.CatBoostClassifier at 0x7fd8e323f400>]

# %%
# Sometimes you want to include the output of the compare_models() as a screenshot into a report. However, with the yellow highlights it gets difficult to read. Pycaret has thought of that and you can use the pull() function to show the model results in the sort by or ascending order.
pull().sort_values(by='Accuracy', ascending=False)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# xgboost         Extreme Gradient Boosting    0.8118  0.8794  0.8080  0.8168
# catboost              CatBoost Classifier    0.7932  0.8716  0.8107  0.7827
# lightgbm  Light Gradient Boosting Machine    0.7929  0.8656  0.7902  0.7881
# et                 Extra Trees Classifier    0.7818  0.8866  0.8108  0.7742
# gbc          Gradient Boosting Classifier    0.7741  0.8606  0.7715  0.7661
# rf               Random Forest Classifier    0.7705  0.8750  0.7669  0.7678
# ada                  Ada Boost Classifier    0.7249  0.7890  0.6963  0.7213
# dt               Decision Tree Classifier    0.6915  0.6996  0.6868  0.6886
# qda       Quadratic Discriminant Analysis    0.6204  0.6948  0.5460  0.6057
# knn                K Neighbors Classifier    0.6197  0.6928  0.6916  0.6073
# nb                            Naive Bayes    0.5979  0.6741  0.5313  0.5977
# lr                    Logistic Regression    0.5974  0.6753  0.5040  0.6017
# lda          Linear Discriminant Analysis    0.5942  0.6948  0.5640  0.5922
# ridge                    Ridge Classifier    0.5751  0.0000  0.5367  0.5760
# svm                   SVM - Linear Kernel    0.5342  0.0000  0.6877  0.5008
#
#               F1   Kappa     MCC  TT (Sec)
# xgboost   0.7974  0.6217  0.6409     0.258
# catboost  0.7830  0.5827  0.5991     2.401
# lightgbm  0.7770  0.5790  0.5942     0.024
# et        0.7767  0.5642  0.5839     0.098
# gbc       0.7570  0.5458  0.5599     0.061
# rf        0.7559  0.5391  0.5522     0.126
# ada       0.6994  0.4441  0.4527     0.049
# dt        0.6744  0.3821  0.3958     0.009
# qda       0.5686  0.2214  0.2264     0.010
# knn       0.6257  0.2682  0.2837     0.015
# nb        0.5522  0.1902  0.1996     0.007
# lr        0.5334  0.1895  0.2006     0.612
# lda       0.5627  0.1914  0.1990     0.008
# ridge     0.5408  0.1577  0.1652     0.007
# svm       0.5128  0.0891  0.1231     0.009

# %%
#i = ['et', 'gbc', 'xgboost']

select_tuned = [tune_model(i, n_iter=120, optimize='Accuracy', fold=10, search_library='optuna', search_algorithm='random') for i in select_top]
# Out:
# <style  type="text/css" >
#     #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_7bae05ee_46ea_11eb_a706_acde48001122row10_col6 {
#             background:  yellow;
#         }</style><table id="T_7bae05ee_46ea_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col0" class="data row0 col0" >0.7407</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.8626</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.6429</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.8182</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.7200</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.4850</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.4973</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col0" class="data row1 col0" >0.8519</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col1" class="data row1 col1" >0.9722</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col2" class="data row1 col2" >0.7333</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col4" class="data row1 col4" >0.8462</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col5" class="data row1 col5" >0.7097</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row1_col6" class="data row1 col6" >0.7416</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col0" class="data row2 col0" >0.8148</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col1" class="data row2 col1" >0.9211</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col3" class="data row2 col3" >0.6154</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col4" class="data row2 col4" >0.7619</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col5" class="data row2 col5" >0.6240</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row2_col6" class="data row2 col6" >0.6734</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col0" class="data row3 col0" >0.7778</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col1" class="data row3 col1" >0.8722</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col2" class="data row3 col2" >0.8333</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col3" class="data row3 col3" >0.7143</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col4" class="data row3 col4" >0.7692</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col5" class="data row3 col5" >0.5574</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row3_col6" class="data row3 col6" >0.5635</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col0" class="data row4 col0" >0.7037</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col1" class="data row4 col1" >0.8158</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col2" class="data row4 col2" >0.8750</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col3" class="data row4 col3" >0.5000</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col4" class="data row4 col4" >0.6364</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col5" class="data row4 col5" >0.4162</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row4_col6" class="data row4 col6" >0.4629</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col0" class="data row5 col0" >0.9259</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col1" class="data row5 col1" >0.9886</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col2" class="data row5 col2" >0.9375</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col3" class="data row5 col3" >0.9375</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col4" class="data row5 col4" >0.9375</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col5" class="data row5 col5" >0.8466</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row5_col6" class="data row5 col6" >0.8466</td>
#             </tr>
#             <tr>
#                         <th id="T_7bae05ee_46ea_11eb_a706_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col0" class="data row6 col0" >0.9231</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col1" class="data row6 col1" >0.9464</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col2" class="data row6 col2" >0.8571</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col4" class="data row6 col4" >0.9231</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_acde48001122row6_col5" class="data row6 col5" >0.8471</td>
#                         <td id="T_7bae05ee_46ea_11eb_a706_a

# %%
# Blending models is an ensemble method of combining different machine learning algorithms and use a majority vote to build consensus of final prediction values. Let's try building a blending model from our top 5 models and evaluate the results. 
blender_specific = blend_models(estimator_list=select_tuned[0:], fold=10, optimize='Accuracy', choose_better=True)
# Out:
# <style  type="text/css" >
#     #T_84caf786_46ea_11eb_a706_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_84caf786_46ea_11eb_a706_acde48001122row10_col6 {
#             background:  yellow;
#         }</style><table id="T_84caf786_46ea_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col0" class="data row0 col0" >0.7407</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.8407</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.7857</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.7333</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.7586</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.4793</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.4807</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col0" class="data row1 col0" >0.9259</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col1" class="data row1 col1" >0.9889</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col2" class="data row1 col2" >0.9333</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col3" class="data row1 col3" >0.9333</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col4" class="data row1 col4" >0.9333</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col5" class="data row1 col5" >0.8500</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row1_col6" class="data row1 col6" >0.8500</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col0" class="data row2 col0" >0.7778</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col1" class="data row2 col1" >0.9408</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col3" class="data row2 col3" >0.5714</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col4" class="data row2 col4" >0.7273</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col5" class="data row2 col5" >0.5622</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row2_col6" class="data row2 col6" >0.6253</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col0" class="data row3 col0" >0.7778</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col1" class="data row3 col1" >0.8889</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col2" class="data row3 col2" >1.0000</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col3" class="data row3 col3" >0.6667</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col4" class="data row3 col4" >0.8000</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col5" class="data row3 col5" >0.5714</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row3_col6" class="data row3 col6" >0.6325</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col0" class="data row4 col0" >0.6296</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col1" class="data row4 col1" >0.8092</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col2" class="data row4 col2" >0.8750</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col3" class="data row4 col3" >0.4375</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col4" class="data row4 col4" >0.5833</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col5" class="data row4 col5" >0.3112</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row4_col6" class="data row4 col6" >0.3730</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col0" class="data row5 col0" >0.9630</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col1" class="data row5 col1" >1.0000</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col2" class="data row5 col2" >1.0000</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col3" class="data row5 col3" >0.9412</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col4" class="data row5 col4" >0.9697</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col5" class="data row5 col5" >0.9222</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row5_col6" class="data row5 col6" >0.9250</td>
#             </tr>
#             <tr>
#                         <th id="T_84caf786_46ea_11eb_a706_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col0" class="data row6 col0" >0.8462</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col1" class="data row6 col1" >0.9524</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col2" class="data row6 col2" >0.9286</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col3" class="data row6 col3" >0.8125</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col4" class="data row6 col4" >0.8667</td>
#                         <td id="T_84caf786_46ea_11eb_a706_acde48001122row6_col5" class="data row6 col5" >0.6867</td>
#                         <td id="T_84caf786_46ea_11eb_a706_a

# %%
# Below is a view of the model parameters. 
blender_specific

# %%
optimized_threshold = optimize_threshold(blender_specific, true_negative=50, false_negative=0, false_positive=-50, true_positive=50)
# Out:
# Optimized Probability Threshold: 0.7344 | Optimized Cost Function: 3800

# %% [markdown]
# ## 5. Evaluate Results and Finalize Model

# %%
evaluate_model(blender_specific)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
available_plots = ['residuals', 'error', 'cooks', 'auc', 'threshold', 'pr', 'confusion_matrix', 'class_report', 'boundary', 'rfe', 'learning', 'manifold', 'calibration', 'vc', 'dimension', 'feature', 'feature_all', 'parameter', 'lift', 'gain', 'tree']

for p in available_plots:
    try:
        plot_model(blender_specific, plot=p, scale=2, save=True, verbose=False)
        print(p, 'printed')
    except:
        print(p, 'not printed')
# Out:
# residuals not printed
# error printed
# cooks not printed
# auc printed
# threshold printed
# pr printed
# confusion_matrix printed
# class_report printed
# boundary not printed
# rfe printed
# learning printed
# manifold not printed
# calibration printed
# vc printed
# dimension not printed
# feature printed
# feature_all not printed
# parameter printed
# lift printed
# gain printed
# tree not printed

# %%
# We can execute the predict_model() function to use the model to generate the predicted values. 
pred_tunded_blender = predict_model(blender_specific)
# Out:
# <style  type="text/css" >
# </style><table id="T_76440a8a_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76440a8a_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.8095</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.8250</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.7174</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7674</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.6075</td>
#                         <td id="T_76440a8a_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.6117</td>
#             </tr>
#     </tbody></table>

# %%
pred_tunded_blender = predict_model(blender_specific, probability_threshold=optimized_threshold)
# Out:
# <style  type="text/css" >
# </style><table id="T_768dab9a_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_768dab9a_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7524</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.4250</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.8500</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.5667</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.4191</td>
#                         <td id="T_768dab9a_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.4685</td>
#             </tr>
#     </tbody></table>

# %%
import numpy as np 

i = np.random.random_sample(10,)
i.sort()

for i in i:
    try:
        predict_model(blender_specific, probability_threshold=float(i))
        print(i)
    except:
        print("error")
# Out:
# <style  type="text/css" >
# </style><table id="T_77b297ba_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77b297ba_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.4190</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.3960</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.5674</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.0476</td>
#                         <td id="T_77b297ba_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.1561</td>
#             </tr>
#     </tbody></table>
# 0.07623586392463244
# <style  type="text/css" >
# </style><table id="T_77c54ebe_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77c54ebe_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7524</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.9500</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.6129</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7451</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.5252</td>
#                         <td id="T_77c54ebe_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.5735</td>
#             </tr>
#     </tbody></table>
# 0.3074450957264464
# <style  type="text/css" >
# </style><table id="T_77d92538_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77d92538_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7714</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.9500</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.6333</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7600</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.5579</td>
#                         <td id="T_77d92538_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.6001</td>
#             </tr>
#     </tbody></table>
# 0.3265540380970211
# <style  type="text/css" >
# </style><table id="T_77eddb86_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77eddb86_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7714</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.8500</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.6538</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7391</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.5418</td>
#                         <td id="T_77eddb86_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.5566</td>
#             </tr>
#     </tbody></table>
# 0.3765721937345584
# <style  type="text/css" >
# </style><table id="T_78017970_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78017970_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7619</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.8250</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.6471</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7253</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.5205</td>
#                         <td id="T_78017970_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.5325</td>
#             </tr>
#     </tbody></table>
# 0.38668980365091743
# <style  type="text/css" >
# </style><table id="T_78160a52_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78160a52_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.8095</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.8250</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.7174</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.7674</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.6075</td>
#                         <td id="T_78160a52_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.6117</td>
#             </tr>
#     </tbody></table>
# 0.48312193697689365
# <style  type="text/css" >
# </style><table id="T_782b745a_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_782b745a_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.7429</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.4000</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.8421</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.5424</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.3936</td>
#                         <td id="T_782b745a_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.4463</td>
#             </tr>
#     </tbody></table>
# 0.7566816218840872
# <style  type="text/css" >
# </style><table id="T_78400a14_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78400a14_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.6571</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.1000</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.1818</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.1209</td>
#                         <td id="T_78400a14_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.2537</td>
#             </tr>
#     </tbody></table>
# 0.8738546095475132
# <style  type="text/css" >
# </style><table id="T_7853a04c_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7853a04c_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.6476</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.0750</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.1395</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.0912</td>
#                         <td id="T_7853a04c_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.2186</td>
#             </tr>
#     </tbody></table>
# 0.8939188951241261
# <style  type="text/css" >
# </style><table id="T_7866a250_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7866a250_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >0.6190</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >0.8681</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >0.0000</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >0.0000</td>
#                         <td id="T_7866a250_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >0.0000</td>
#             </tr>
#     </tbody></table>
# 0.940817868817902

# %%
# The Blend model seems to perform better in both our train and test so let us finalize it. The finalize_model() function trains the model on the entire dataset. 
finalize_blender = finalize_model(blender_specific)
finalize_blender

# %%
predict_model(finalize_blender, probability_threshold=0.50)
# Out:
# <style  type="text/css" >
# </style><table id="T_5b141ef8_46eb_11eb_a706_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b141ef8_46eb_11eb_a706_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col5" class="data row0 col5" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col6" class="data row0 col6" >1.0000</td>
#                         <td id="T_5b141ef8_46eb_11eb_a706_acde48001122row0_col7" class="data row0 col7" >1.0000</td>
#             </tr>
#     </tbody></table>
#          Friday      Sunday   Thursday     Tuesday   Wednesday    Saturday  \
# 0     92.666000   93.750000  95.906540  100.000000   99.505837   90.000000
# 1     90.475716  100.000000  91.371429   92.856667   95.778000   87.052498
# 2     95.238571   96.428574  94.775528  100.000000   95.327909   98.750000
# 3    100.000000   98.073858  95.238571   97.916252   94.734283  100.000000
# 4    100.000000   92.279742  92.215714   96.129997   97.500000   94.641998
# ..          ...         ...        ...         ...         ...         ...
# 100   91.910613  100.000000  90.248594  100.000000  100.000000  100.000000
# 101   77.779999   92.363998  97.077499   96.686249   97.681427   96.476716
# 102   91.468002   91.112000  86.688098   96.666000   91.936459  100.000000
# 103   98.214287   88.229401  87.083748   95.237144   87.381248   85.713753
# 104   88.888336   92.065488  81.250000   85.185555  100.000000   96.673321
#
#      Wednesday_multiply_Tuesday  Sunday_multiply_Friday actualvalue_class  \
# 0                   9950.583670             8687.437534                 0
# 1                   8893.625799             9047.571564                 0
# 2                   9532.790911             9183.719570                 1
# 3                   9276.025984             9807.385814                 0
# 4                   9372.674732             9227.974185                 0
# ..                          ...                     ...               ...
# 100                10000.000000             9191.061253                 0
# 101                 9444.450752             7184.071684                 1
# 102                 8887.129746             8333.832583                 0
# 103                 8321.940585             8665.387674                 0
# 104                 8518.555450             8183.548059                 1
#
#      Label   Score
# 0        0  0.6694
# 1        0  0.8104
# 2        1  0.8823
# 3        0  0.7345
# 4        0  0.8567
# ..     ...     ...
# 100      0  0.7603
# 101      1  0.9585
# 102      0  0.8278
# 103      0  0.9406
# 104      1  0.8438
#
# [105 rows x 11 columns]

# %% [markdown]
# ## 6. Analyze the Performance of Final Model on Entire Dataset

# %%
# The predict_model() can be executed with the final blend model over the entire dataset and saved to a csv file. 
pred_final_blender = predict_model(finalize_blender, data=dataset)
pred_final_blender.to_csv('pred_final_blender.csv')
pred_final_blender.describe()
# Out:
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
# Finished loading model, total used 100 iterations
#        Unnamed: 0    employeeid      Friday      Monday    Saturday  \
# count  418.000000  4.180000e+02  388.000000  359.000000  322.000000
# mean   248.464115  2.676806e+07   95.266572   94.403712   95.453846
# std    141.333440  7.608682e+05    5.370665    5.534483    4.429499
# min      3.000000  2.670251e+07   67.857500   70.832500   77.776667
# 25%    125.250000  2.670320e+07   93.334000   91.666667   92.628259
# 50%    250.000000  2.670353e+07   96.186000   95.312500   96.295000
# 75%    374.750000  2.670381e+07  100.000000  100.000000  100.000000
# max    488.000000  3.570632e+07  100.000000  100.000000  100.000000
#
#            Sunday    Thursday     Tuesday   Wednesday  weekbefore  \
# count  256.000000  306.000000  407.000000  333.000000  415.000000
# mean    94.734393   94.221967   95.195005   94.916940   95.177928
# std      6.077321    5.895096    4.890178    7.137471    9.941633
# min     50.000000   57.500000   61.666000   50.000000   33.330000
# 25%     92.466000   91.666875   93.446667   92.855000   93.330000
# 50%     95.989375   95.758375   96.010000   96.666667  100.000000
# 75%    100.000000   98.411458   98.437500  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000
#
#        ncoachingid  total coaching improved        csat  actualvalue  \
# count   312.000000                256.00000  418.000000   418.000000
# mean      3.496795                  2.37500   94.867464    94.365933
# std       2.871300                  1.57181    1.833150     5.818415
# min       1.000000                  1.00000   79.260000    50.000000
# 25%       2.000000                  1.00000   93.970000    91.300000
# 50%       3.000000                  2.00000   95.085000    95.740000
# 75%       4.000000                  3.00000   96.062500   100.000000
# max      16.000000                  8.00000   99.220000   100.000000
#
#        actualvalue_class       Label       Score
# count          418.00000  418.000000  418.000000
# mean             0.46890    0.466507    0.825681
# std              0.49963    0.499475    0.096979
# min              0.00000    0.000000    0.514500
# 25%              0.00000    0.000000    0.780825
# 50%              0.00000    0.000000    0.845050
# 75%              1.00000    1.000000    0.897050
# max              1.00000    1.000000    0.961700

# %%
# We can use the Pycaret's built-in plot_model() function to generate Residuals and Error plots for the finalized blend model. 
fig = plt.figure(figsize=(9,10))
ax = fig.add_subplot(2,1,1)
plot_model(finalize_blender, plot='residuals', save=True, verbose=False, scale=1.1)
ax = fig.add_subplot(2,1,2)
plot_model(finalize_blender, plot='error', save=True, verbose=False, scale=1.1)
plt.savefig('plots_pred_final_blender.png', dpi=300, pad_inches=0.25)
plt.show()
# Out:
# Finished loading model, total used 130 iterations
# Finished loading model, total used 130 iterations

# %%
# An interesting view is looking at the Actual Values and Predicted Values (Label) in a histogram over the entire dataset. This shows the distribution between the values. We can see how the Predicted Values seem to peak in a more distributed manner and skew to the left. 
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")
sns.distplot(pred_final_blender["Actual Value"],
                bins=20,
                kde=False,
                color="#c6690c")
sns.distplot(pred_final_blender["Label"],
                bins=20,
                kde=False,
                color="#664697")
plt.title("Distribution between Actual Value and Predicted Value (Label)")
plt.ylabel("Count")
plt.xlabel("FCR Value")
plt.xlim((74,101))
plt.legend(('Actual Value', 'Predicted Value (Label)'), ncol=2, loc='upper left', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-91dafb35846c> in <module>
#       2 plt.figure(figsize=(15,5))
#       3 sns.set_style("whitegrid")
# ----> 4 sns.distplot(pred_final_blender["Actual Value"],
#       5                 bins=20,
#       6                 kde=False,
#
# NameError: name 'pred_final_blender' is not defined

# %%
# We can plot the Predicted Value (Label) and Actual Value over the entire dataset. 
sns.regplot(x="Actual Value", y="Label", data=pred_final_blender, lowess=False, scatter_kws ={'s':50}, line_kws={"color": "#664697"}, color="#c6690c")
plt.title("Linear Relationship between Actual Value and Predicted Value (Label)")
plt.ylabel("Predicted Value (Label)")
plt.xlabel("Actual Value")
plt.xlim((74,101))
plt.legend(('Best Fit', 'Actual Value vs Predicted Value (Label)'), ncol=2, loc='upper left', fontsize=12)

# %%
# We can compare the Predicted Values (Label) and Residuals in an error plot over the entire dataset. 
sns.residplot(x="Actual Value", y="Label", data=pred_final_blender, lowess=False, scatter_kws ={'s':50}, line_kws={"color": "#664697"}, color="#c6690c")
plt.title("Residuals for the Predicted values in Final Blend Model")
plt.ylabel("Residuals")
plt.xlabel("Predicted Value (Label)")
plt.xlim((74,101))
plt.legend(('Best Fit', 'Predicted Value (Label)'), ncol=2, loc='upper left', fontsize=12)

# %% [markdown]
# ## 7. Client Presentation and Next Steps
#
# We presented the results of our experiment to the client, thinking they would be impressed. Initially, they shared their excitement of leveraging the models to predict performance. However, having a RMSE of ~4.5 is not going to be viewed in a positive manner with employees and their supervisors.
#
# However, we decided to approach it differently. Instead of looking at a finite value, we determined that if we can predict whether the employee was going to increase or decrease performance then this would be quite beneficial. In particular, if we can determine that the employee's performance was going to decrease then the supervisor can preempt it and try to mitigate the decrease in employee's performance before it occurs.

# %%
# Generating the classification label based on the regression analysis. 
pred_final_blender.loc[(pred_final_blender['Actual Value'] >= pred_final_blender['FCR Week before']) & (pred_final_blender['Label'] > pred_final_blender['FCR Week before']), 'Pred_Class'] = 'True Positive'

pred_final_blender.loc[(pred_final_blender['Actual Value'] < pred_final_blender['FCR Week before']) & (pred_final_blender['Label'] < pred_final_blender['FCR Week before']), 'Pred_Class'] = 'True Negative'

pred_final_blender.loc[(pred_final_blender['Actual Value'] >= pred_final_blender['FCR Week before']) & (pred_final_blender['Label'] < pred_final_blender['FCR Week before']), 'Pred_Class'] = 'False Negative'

pred_final_blender.loc[(pred_final_blender['Actual Value'] < pred_final_blender['FCR Week before']) & (pred_final_blender['Label'] > pred_final_blender['FCR Week before']), 'Pred_Class'] = 'False Positive'

# %%
# Saving the classification results to a CSV file and create a data type to store the classification metrics. 
pred_final_blender
pred_final_blender.to_csv('pred_final_blender.csv')

cf_values = pred_final_blender['Pred_Class'].value_counts()
cf_values
# Out:
# True Positive     45
# True Negative     28
# False Negative    25
# False Positive     4
# Name: Pred_Class, dtype: int64

# %%
# Create confusion matrix table, along with labels, counts and percentage
cf_matrix = np.array([[cf_values.loc['True Positive'], cf_values.loc['False Negative']],
            [cf_values.loc['False Positive'], cf_values.loc['True Negative']]])

group_names = ['True Positive', 'False Negative\n(Type II Error)', 'False Positive\n(Type I Error)', 'True Negative']

group_counts = ['{0:0.0f}'.format(value) for value in
                cf_matrix.flatten()]
                
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
                     
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
          
labels = np.asarray(labels).reshape(2,2)

# Create confusion matrix plot using Seaborn
ax = plt.subplot()
plt.rcParams.update({'font.size': 14})
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='PuOr')

# Set labels, title and ticks
ax.set_xlabel('Predicted Class', fontsize=14)
ax.set_ylabel('Actual Class', fontsize=14)
ax.set_title('Confusion Matrix', fontsize=14, fontweight='bold')
ax.xaxis.set_ticklabels(['Performance Increase', 'Performance Decrease'], fontsize=12)
ax.yaxis.set_ticklabels(['Performance Increase', 'Performance Decrease'], va='center', fontsize=12)
# Out:
# [Text(0, 0.5, 'Performance Increase'), Text(0, 1.5, 'Performance Decrease')]

# %%
# Below are the classification metrics. 
accuracy = '{0:.2%}'.format((cf_values.loc['True Positive'] + cf_values.loc['True Negative']) / (cf_values.loc['True Positive'] + cf_values.loc['False Positive'] + cf_values.loc['True Negative'] + cf_values.loc['False Negative']))
print('Accuracy: ', accuracy)

sensitivity = '{0:.2%}'.format((cf_values.loc['True Positive']) / (cf_values.loc['True Positive'] + cf_values.loc['False Negative']))
print('Sensitivity (Recall): ', sensitivity)

specificity = '{0:.2%}'.format((cf_values.loc['True Negative']) / (cf_values.loc['True Negative'] + cf_values.loc['False Positive']))
print('Specificity (True Negative Rate): ', specificity)

precision = '{0:.2%}'.format((cf_values.loc['True Positive']) / (cf_values.loc['True Positive'] + cf_values.loc['False Positive']))
print('Precision (Positive Predictive Value): ', precision)

f1 = '{0:.2%}'.format((2 * cf_values.loc['True Positive']) / (2 * cf_values.loc['True Positive'] + cf_values.loc['False Positive'] + cf_values.loc['False Negative']))
print('F1 Score (harmonic mean of Precision and Sensitivity): ', f1)
# Out:
# Accuracy:  71.57%
# Sensitivity (Recall):  64.29%
# Specificity (True Negative Rate):  87.50%
# Precision (Positive Predictive Value):  91.84%
# F1 Score (harmonic mean of Precision and Sensitivity):  75.63%

# %% [markdown]
# ## 8. Conclusion
#
# Getting accuracy over 70% is more likely to move this model in to production. We can confidently predict whether the employee will increase or decrease in performance. Even more so, for employees we think will decrease in performance, we can get ahead of that and ask the supervisor to coach them and support them to mitigate the decrease in performance.
#
# We can see how versatile Pycaret is in experimenting real case scenarios. Most companies do not have terabytes of data so as a citizen-data-scientists, we can use Pycaret in many daily business situations to make more meaningful and data-driven decisions.

# %%
# Note: since we had enabled log_experiement and log_plots in the setup() function. Pycaret does a wonderful job in leveraging MLflow so all experiments can be logged and analyzed. This can be accomplished with a simple one-line command and viewed in your browser. 
# !mlflow ui
# Out:
# [2020-09-04 12:00:01 -0500] [16848] [INFO] Starting gunicorn 20.0.4
# [2020-09-04 12:00:01 -0500] [16848] [INFO] Listening at: http://127.0.0.1:5000 (16848)
# [2020-09-04 12:00:01 -0500] [16848] [INFO] Using worker: sync
# [2020-09-04 12:00:01 -0500] [16850] [INFO] Booting worker with pid: 16850
# ^C
# [2020-09-04 12:14:16 -0500] [16848] [INFO] Handling signal: int
# [2020-09-04 12:14:16 -0500] [16850] [INFO] Worker exiting (pid: 16850)

# %% [markdown]
# ![Screen%20Shot%202020-09-04%20at%2010.10.33%20AM.png](attachment:Screen%20Shot%202020-09-04%20at%2010.10.33%20AM.png)

# %% [markdown]
# ## 9. Sources and References
#
# Matplotlib. Retrieved August 24, 2020, from https://matplotlib.org
#
# Numpy. Retrieved August 24, 2020, from https://numpy.org/
#
# Pandas. Retrieved August 24, 2020, from https://pandas.pydata.org/
#
# Pycaret. (2020, May 11). Retrieved August 24, 2020, from https://pycaret.org/
#
# Python. Retrieved August 24, 2020, from https://www.python.org/
#
# Scikit Learn: Learn. Retrieved August 24, 2020, from https://scikit-learn.org/
#
# Seaborn. Retrieved August 24, 2020, from https://seaborn.pydata.org/
